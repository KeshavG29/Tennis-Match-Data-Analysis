# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("tennis.csv")

# %%
data.head(10)
# Out:
#    rally  serve hitpoint      speed  net.clearance  distance.from.sideline  \
# 0      4      1        B  35.515042      -0.021725                3.474766
# 1      4      2        B  33.382640       1.114202                2.540801
# 2     23      1        B  22.316690      -0.254046                3.533166
# 3      9      1        F  36.837309       0.766694                0.586885
# 4      4      1        B  35.544208       0.116162                0.918725
# 5     10      1        B  39.012186       0.349889                0.485098
# 6      7      1        B  34.585672       1.234044                3.083445
# 7      3      1        F  34.445742       0.387828                0.873202
# 8     11      2        F  21.830172       0.541135                0.494508
# 9     20      1        F  45.379172       0.265430                1.307053
#
#       depth  outside.sideline  outside.baseline  player.distance.travelled  \
# ...

# %%
data.shape
# Out:
# (8001, 27)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8001 entries, 0 to 8000
# Data columns (total 27 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   rally                               8001 non-null   int64
#  1   serve                               8001 non-null   int64
#  2   hitpoint                            8001 non-null   object
#  3   speed                               8001 non-null   float64
#  4   net.clearance                       8001 non-null   float64
#  5   distance.from.sideline              8001 non-null   float64
#  6   depth                               8001 non-null   float64
#  7   outside.sideline                    8001 non-null   bool
#  8   outside.baseline                    8001 non-null   bool
#  9   player.distance.travelled           8001 non-null   float64
#  10  player.impact.depth                 8001 non-null   float64
# ...

# %%
data.describe().T
# Out:
#                                      count         mean          std  \
# rally                               8001.0     5.966004     3.548182
# serve                               8001.0     1.398700     0.489661
# speed                               8001.0    30.806938     7.298917
# net.clearance                       8001.0     0.629658     0.982504
# distance.from.sideline              8001.0     1.467630     1.108697
# depth                               8001.0     4.421146     3.144965
# player.distance.travelled           8001.0     2.690463     1.713136
# player.impact.depth                 8001.0    11.899694     2.788231
# player.impact.distance.from.center  8001.0     1.919544     1.205449
# player.depth                        8001.0    12.253954     2.039085
# player.distance.from.center         8001.0     1.213795     0.964364
# previous.speed                      8001.0    28.763676     6.477470
# previous.net.clearance              8001.0     0.821562     0.674663
# ...
